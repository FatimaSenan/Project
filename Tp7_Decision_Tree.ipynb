# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaSenan/Project/blob/main/Tp7_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade nbconvert

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-01a91318-7abc-4070-a344-d73ce5c75198" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01a91318-7abc-4070-a344-d73ce5c75198">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/glass_data.csv")
df.head()
# Out:
#    Id  refractive index  Sodium  Magnesium  Aluminium  Silicon  Potassium  \
# 0   1           1.52101   13.64       4.49       1.10    71.78       0.06
# 1   2           1.51761   13.89       3.60       1.36    72.73       0.48
# 2   3           1.51618   13.53       3.55       1.54    72.99       0.39
# 3   4           1.51766   13.21       3.69       1.29    72.61       0.57
# 4   5           1.51742   13.27       3.62       1.24    73.08       0.55
#
#    Calcium  Barium  Iron  Type
# 0     8.75     0.0   0.0     1
# 1     7.83     0.0   0.0     1
# 2     7.78     0.0   0.0     1
# 3     8.22     0.0   0.0     1
# 4     8.07     0.0   0.0     1

# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
X_train, X_test, y_train, y_test = train_test_split(df[df.columns.drop('Type')], df.Type, train_size=0.7, random_state=0)
